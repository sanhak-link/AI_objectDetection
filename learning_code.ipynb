# %%
#구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')

# %%
# YOLOv8 Ultralytics 라이브러리
# !pip install ultralytics

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="5o4lpZk6ZP5jyLSElJPW")
project = rf.workspace("taekyung").project("merge_knife_dataset-a4xfd")
version = project.version(1)
dataset = version.download("yolov8")

# %%
# YOLOv8 모델 학습 코드 
# model 인수 : 이전 학습 결과의 best.pt 파일 경로

# !yolo train model='/content/drive/MyDrive/SmartShield_results/knife_v1_100epochs/weights/best.pt' data='/content/merge_knife_dataset-1/data.yaml' epochs=100 project='/content/drive/MyDrive/SmartShield_results' name='knife_v2_merged_100epochs'

# %%
# 사진 테스트를 위한 코드
# 'model' 경로: 이전에 학습하여 Drive에 저장된 best.pt 파일의 경로
# 'source' 경로: 방금 이미지를 업로드한 폴더 경로

# !yolo predict model='/content/drive/MyDrive/SmartShield_results/knife_v2_merged_100epochs/weights/best.pt' source='/content/my_data/'
